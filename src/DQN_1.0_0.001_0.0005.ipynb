# %%
#!pip3 install box2d-py
#!pip3 install gym[Box_2D]
import numpy as np
import gym
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.callbacks import TensorBoard
import random
from collections import deque
import pandas as pd
from tqdm import tqdm
import time as time

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.animation as animation
mpl.rc('animation', html='jshtml')

# %%
tf.compat.v1.disable_eager_execution()

# %%
## Enable this code to disable the GPU execution

physical_devices = tf.config.list_physical_devices('GPU')
try:
  # Disable all GPUS
  tf.config.set_visible_devices([], 'GPU')
  visible_devices = tf.config.get_visible_devices()
  for device in visible_devices:
    assert device.device_type != 'GPU'
except:
  # Invalid device or cannot modify virtual devices once initialized.
  pass

# %%
class DQN():
    
    def __init__(self, game, retrain = False, epsilon=1, epsilon_decay = 0.995, 
                 epsilon_min = 0.1, batch_size = 64, discount_factor=0.99, episodes=1000, alpha = 0.01, lr=0.001):
        
        self.ep = epsilon
        self.ep_decay = epsilon_decay
        self.ep_min = epsilon_min
        self.batch_size = batch_size
        self.gamma = discount_factor
        self.episodes = episodes
        self.game = game
        self.alpha = alpha
        self.lr = lr
        self.retrain = retrain
        
        self.frames = []
        
        seed = 983827
        mem = 1000000

        self.csv_filename = "ep100_0p001_0p0005.csv"
        self.model_filename = "ep100_0p001_0p0005.h5"

        
        self.env = gym.make(game)
        self.env.seed(seed)
        
        keras.backend.clear_session()
        
        tf.random.set_seed(seed)
        np.random.seed(seed)
        
        self.nS = self.env.observation_space.shape[0]
        self.nA = self.env.action_space.n
        
        print("state size is: ",self.nS)
        print("action size is: ", self.nA)
       
        
        self.memory = deque(maxlen=1000000)  #Creating a container to replay meomory, double linked list.

        if self.retrain == False:
          self.Q_model = self.setup_dnn()
          self.Q_hat_model = self.setup_dnn()
          print("NEW MODEL CREATED!")
        
        else:

          self.Q_model = tf.keras.models.load_model(self.model_filename)
          self.Q_hat_model = tf.keras.models.load_model(self.model_filename)
          print("MODEL LOADED!")
          self.Q_model.summary()


        self.counter = 0
        self.update_freq = 4

        
        self.df_ddqn = pd.DataFrame(columns = ["Episode", "Epsilon", "Reward", "Mean_Reward", "Time"])
        
    def setup_dnn(self):
        
        input_ = tf.keras.layers.Input(shape = (self.nS))
        
        hidden1_ = tf.keras.layers.Dense(64, activation = "relu")(input_)
        hidden2_ = tf.keras.layers.Dense(64, activation = "relu")(hidden1_)
        output_ = tf.keras.layers.Dense(self.nA)(hidden2_)
        
        model_ = tf.keras.Model(inputs = [input_], outputs = [output_])
        opt_ = tf.keras.optimizers.Adam(self.lr)
        model_.compile(optimizer = opt_, loss = "mse")
        
        return model_
    
    def action(self, state, epsilon):
        
        if np.random.rand() < epsilon:
            return self.env.action_space.sample()
        else:
            Q_values = self.Q_model.predict(state) #Greedy policy w.r.t Q
            
        return np.argmax(Q_values[0])
    
    
    def store(self, state, action, reward, next_state, done):
        
        self.memory.append((state, action, reward, next_state, done))
        
    
    def weights_update(self):
        Q_w = self.Q_model.get_weights()
        Q_hat_w = self.Q_hat_model.get_weights()
        
        for w in range(len(Q_hat_w)):
            Q_hat_w[w] = self.alpha * Q_w[w] + (1-self.alpha) * Q_hat_w[w]
        
        self.Q_hat_model.set_weights(Q_hat_weights)
        

    '''
        
    def learn(self):
        
        if self.ep > self.ep_min:
            self.ep *= self.ep_decay
        
        samples = random.choices(self.memory, k = self.batch_size)
        
        for state, action, reward, next_state, done in samples:
            target = reward
            
            if not done:
                target = reward + self.gamma*np.max(self.model.predict(next_state)[0])
            
            end_target = self.model.predict(state)
            end_target[0][action] = target
            
            self.history = self.model.fit(state, end_target, verbose = 0)
    '''
    
    def learn_batch(self):
             
        self.counter = (self.counter + 1) % self.update_freq
        
        if self.counter == 0:
            #print("Learning...")
            if len(self.memory) < self.batch_size:
                return
            
            states, end_targets = [], []
            
            samples = random.choices(self.memory, k = self.batch_size)
            
            for state, action, reward, next_state, done in samples:
                target = reward
            
                if not done:
                    target = reward + self.gamma*np.max(self.Q_hat_model.predict(next_state)[0])
            
                end_target = self.Q_model.predict(state)
                end_target[0][action] = target
                
                states.append(state[0])
                end_targets.append(end_target[0])
            
            self.Q_model.fit(np.array(states), np.array(end_targets), verbose = 0, epochs = 1)
            
            Q_w = self.Q_model.get_weights()
            Q_hat_w = self.Q_hat_model.get_weights()
        
            for w in range(len(Q_hat_w)):
                Q_hat_w[w] = self.alpha * Q_w[w] + (1-self.alpha) * Q_hat_w[w]
        
            self.Q_hat_model.set_weights(Q_hat_w)
    
    
    def play(self): 
        
        new_row = {}
        R = []
        R_moving = deque(maxlen=100)
        steps = 500
        
        for e in range(self.episodes):
            current_state = self.env.reset()
            current_state = np.reshape(current_state, [1,current_state.shape[0]])
         
            time = 0
            r = 0
            
            for s in range(steps):

                action_ = self.action(current_state, self.ep)
               
                next_state, reward, done, info = self.env.step(action_)
                
                next_state = np.reshape(next_state, [1, next_state.shape[0]])
                
                self.store(current_state, action_, reward, next_state, done)
                
                r = r+reward
                
                #self.learn()
                self.learn_batch()
                
                current_state = next_state
                time = time+1
                
                if done:
                    break
            
            #self.learn_batch()
            R.append(r)
            R_moving.append(r)

                    
            new_row = {'Episode':e, 'Epsilon':self.ep, 'Reward': r, 'Mean_Reward':np.mean(R_moving), 'Time':time}
            self.df_ddqn = self.df_ddqn.append(new_row, ignore_index = True)
            
            
            if e % 5 == 0:
              print("Episode: ", e, " , Epsilon: ", self.ep, ', Reward', r,", mean_reward: ",np.mean(R_moving) ,", time_score: ", time, ", memory: ", len(self.memory))

            if e % 100 == 0:

              self.Q_model.save(self.model_filename)
              

            if self.ep > self.ep_min:
              self.ep *= self.ep_decay
            else:
              self.ep = 0.01
            
            if np.mean(R_moving)>= 200.0:
                print("BRAVO, GOAL ACHIEVED!!!")
                break

        with open(self.csv_filename, 'a') as f:
          self.df_ddqn.to_csv(f, header=f.tell()==0, index=False)
             
            
        self.Q_model.save(self.model_filename)
        
        self.env.close()
        
        return self.df_ddqn

# %%
game = "LunarLander-v2"
dqn = DQN(game, retrain = False, epsilon=1 , epsilon_decay = 1.0, epsilon_min = 0.01, batch_size = 64, discount_factor=0.99, episodes=2000, alpha = 0.001, lr=0.0005)
df = dqn.play()
# Out:
# state size is:  8
# action size is:  4
# NEW MODEL CREATED!
# C:\Users\User\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\training.py:2342: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Episode:  0  , Epsilon:  1 , Reward -333.6562744092579 , mean_reward:  -333.6562744092579 , time_score:  74 , memory:  74
# Episode:  5  , Epsilon:  1.0 , Reward -271.05184459962163 , mean_reward:  -227.53991733319035 , time_score:  131 , memory:  561
# Episode:  10  , Epsilon:  1.0 , Reward -221.9662553677928 , mean_reward:  -252.71777860611385 , time_score:  98 , memory:  1003
# Episode:  15  , Epsilon:  1.0 , Reward -133.76454791514035 , mean_reward:  -218.74578635632815 , time_score:  93 , memory:  1425
# Episode:  20  , Epsilon:  1.0 , Reward -108.87094093464053 , mean_reward:  -198.90975484125298 , time_score:  58 , memory:  1817
# Episode:  25  , Epsilon:  1.0 , Reward -357.99685186108616 , mean_reward:  -192.21055130435218 , time_score:  82 , memory:  2212
# Episode:  30  , Epsilon:  1.0 , Reward -181.14348103546527 , mean_reward:  -190.20395691043262 , time_score:  91 , memory:  2678
# Episode:  35  , Epsilon:  1.0 , Reward -88.58044074896617 , mean_reward:  -175.79982054136275 , time_score:  74 , memory:  3114
# Episode:  40  , Epsilon:  1.0 , Reward -180.88122142862727 , mean_reward:  -168.90548610130588 , time_score:  65 , memory:  3473
# Episode:  45  , Epsilon:  1.0 , Reward -143.64166608769688 , mean_reward:  -173.161193231671 , time_score:  72 , memory:  3921
# Episode:  50  , Epsilon:  1.0 , Reward -106.99359179870665 , mean_reward:  -169.58963599322362 , time_score:  75 , memory:  4397
# Episode:  55  , Epsilon:  1.0 , Reward -246.04501069897245 , mean_reward:  -176.16940512867495 , time_score:  125 , memory:  4870
# Episode:  60  , Epsilon:  1.0 , Reward -67.53522649854577 , mean_reward:  -173.73091476789486 , time_score:  112 , memory:  5352
# Episode:  65  , Epsilon:  1.0 , Reward -365.8329469154854 , mean_reward:  -175.65647492645482 , time_score:  95 , memory:  5849
# Episode:  70  , Epsilon:  1.0 , Reward -291.73318743334005 , mean_reward:  -174.07635932842103 , time_score:  79 , memory:  6284
# Episode:  75  , Epsilon:  1.0 , Reward -261.9509438138414 , mean_reward:  -172.92290145270516 , time_score:  141 , memory:  6787
# Episode:  80  , Epsilon:  1.0 , Reward -71.06388390079925 , mean_reward:  -172.25607255294898 , time_score:  66 , memory:  7154
# Episode:  85  , Epsilon:  1.0 , Reward 24.863241501487963 , mean_reward:  -173.39791557164895 , time_score:  87 , memory:  7614
# Episode:  90  , Epsilon:  1.0 , Reward -150.57669025833815 , mean_reward:  -170.4288088026546 , time_score:  116 , memory:  8078
# Episode:  95  , Epsilon:  1.0 , Reward -203.9586264731892 , mean_reward:  -173.4927995182854 , time_score:  84 , memory:  8520
# Episode:  100  , Epsilon:  1.0 , Reward -264.7637582489798 , mean_reward:  -171.56693391741635 , time_score:  76 , memory:  9049
# Episode:  105  , Epsilon:  1.0 , Reward -132.1083185482683 , mean_reward:  -169.91887933067926 , time_score:  82 , memory:  9488
# Episode:  110  , Epsilon:  1.0 , Reward -253.9414090480245 , mean_reward:  -164.32221666074915 , time_score:  105 , memory:  9966
# Episode:  115  , Epsilon:  1.0 , Reward -71.79583366041138 , mean_reward:  -165.0808373620128 , time_score:  58 , memory:  10457
# Episode:  120  , Epsilon:  1.0 , Reward -121.9231224005485 , mean_reward:  -165.59739866679095 , time_score:  110 , memory:  10892
# Episode:  125  , Epsilon:  1.0 , Reward -140.5099069099458 , mean_reward:  -166.6222184904295 , time_score:  112 , memory:  11345
# Episode:  130  , Epsilon:  1.0 , Reward -247.54060708719186 , mean_reward:  -166.65359785877123 , time_score:  75 , memory:  11797
# Episode:  135  , Epsilon:  1.0 , Reward -323.07415897721063 , mean_reward:  -171.9830562050053 , time_score:  94 , memory:  12292
# Episode:  140  , Epsilon:  1.0 , Reward -112.83592729769043 , mean_reward:  -173.9705824794173 , time_score:  128 , memory:  12759
# Episode:  145  , Epsilon:  1.0 , Reward -354.4858892499635 , mean_reward:  -173.35000651861785 , time_score:  115 , memory:  13218
# Episode:  150  , Epsilon:  1.0 , Reward -153.81209880807677 , mean_reward:  -172.67257683358352 , time_score:  79 , memory:  13659
# Episode:  155  , Epsilon:  1.0 , Reward -498.1355628683026 , mean_reward:  -169.93299958195564 , time_score:  102 , memory:  14101
# Episode:  160  , Epsilon:  1.0 , Reward -367.61066669284145 , mean_reward:  -171.31213160187625 , time_score:  95 , memory:  14559
# Episode:  165  , Epsilon:  1.0 , Reward -20.989411712104925 , mean_reward:  -169.58996957891293 , time_score:  125 , memory:  15017
# Episode:  170  , Epsilon:  1.0 , Reward -191.27256437692733 , mean_reward:  -171.068705813154 , time_score:  118 , memory:  15493
# Episode:  175  , Epsilon:  1.0 , Reward -10.142155364766936 , mean_reward:  -169.59810101644726 , time_score:  100 , memory:  15995
# Episode:  180  , Epsilon:  1.0 , Reward -105.0472369439291 , mean_reward:  -167.41256492278708 , time_score:  70 , memory:  16383
# Episode:  185  , Epsilon:  1.0 , Reward -259.3579852248039 , mean_reward:  -167.94417144936398 , time_score:  98 , memory:  16764
# Episode:  190  , Epsilon:  1.0 , Reward -313.10030338897883 , mean_reward:  -173.99204270477316 , time_score:  94 , memory:  17221
# Episode:  195  , Epsilon:  1.0 , Reward -130.05117103644375 , mean_reward:  -172.22768045613535 , time_score:  93 , memory:  17681
# Episode:  200  , Epsilon:  1.0 , Reward -152.3466953746152 , mean_reward:  -172.272475463691 , time_score:  106 , memory:  18132
# Episode:  205  , Epsilon:  1.0 , Reward -207.72501094438303 , mean_reward:  -170.52854622283658 , time_score:  76 , memory:  18524
# Episode:  210  , Epsilon:  1.0 , Reward -177.9275299037759 , mean_reward:  -169.767070688474 , time_score:  104 , memory:  18966
# Episode:  215  , Epsilon:  1.0 , Reward -136.1144857780684 , mean_reward:  -170.95710622527892 , time_score:  67 , memory:  19392
# Episode:  220  , Epsilon:  1.0 , Reward -117.18069073422555 , mean_reward:  -174.15059224658486 , time_score:  72 , memory:  19857
# Episode:  225  , Epsilon:  1.0 , Reward -195.2142652137685 , mean_reward:  -174.3723870432918 , time_score:  138 , memory:  20369
# Episode:  230  , Epsilon:  1.0 , Reward -110.68089629781073 , mean_reward:  -172.77296743867407 , time_score:  71 , memory:  20799
# Episode:  235  , Epsilon:  1.0 , Reward -93.337691055668 , mean_reward:  -171.85692848850192 , time_score:  84 , memory:  21268
# Episode:  240  , Epsilon:  1.0 , Reward -166.76740428175287 , mean_reward:  -169.79435414620337 , time_score:  106 , memory:  21691
# Episode:  245  , Epsilon:  1.0 , Reward -47.02172000909661 , mean_reward:  -166.1938606137607 , time_score:  81 , memory:  22060
# Episode:  250  , Epsilon:  1.0 , Reward -90.38974008300485 , mean_reward:  -171.29316852952522 , time_score:  67 , memory:  22555
# Episode:  255  , Epsilon:  1.0 , Reward -156.96683796831343 , mean_reward:  -168.95923510916123 , time_score:  69 , memory:  22969
# Episode:  260  , Epsilon:  1.0 , Reward -164.84676138167146 , mean_reward:  -167.4620950859302 , time_score:  101 , memory:  23430
# Episode:  265  , Epsilon:  1.0 , Reward -50.58128707648253 , mean_reward:  -169.0518918539464 , time_score:  63 , memory:  23860
# Episode:  270  , Epsilon:  1.0 , Reward -211.84500320298264 , mean_reward:  -167.60008267957213 , time_score:  64 , memory:  24255
# Episode:  275  , Epsilon:  1.0 , Reward -136.02476341384465 , mean_reward:  -172.22340639428762 , time_score:  79 , memory:  24673
# Episode:  280  , Epsilon:  1.0 , Reward -406.6537012676629 , mean_reward:  -175.9217543979366 , time_score:  102 , memory:  25169
# Episode:  285  , Epsilon:  1.0 , Reward -194.39863068803973 , mean_reward:  -174.37968745561233 , time_score:  102 , memory:  25632
# Episode:  290  , Epsilon:  1.0 , Reward -215.83863438878234 , mean_reward:  -172.28131894087005 , time_score:  107 , memory:  26102
# Episode:  295  , Epsilon:  1.0 , Reward -396.24160123634294 , mean_reward:  -172.77593991370497 , time_score:  95 , memory:  26576
# Episode:  300  , Epsilon:  1.0 , Reward -86.3397746191745 , mean_reward:  -172.9488769484764 , time_score:  57 , memory:  26973
# Episode:  305  , Epsilon:  1.0 , Reward -94.77393325168697 , mean_reward:  -171.30604772355412 , time_score:  64 , memory:  27409
# Episode:  310  , Epsilon:  1.0 , Reward -49.860603408024105 , mean_reward:  -171.46990748436056 , time_score:  66 , memory:  27851
# Episode:  315  , Epsilon:  1.0 , Reward -167.66548527533456 , mean_reward:  -171.8324171813609 , time_score:  118 , memory:  28372
# Episode:  320  , Epsilon:  1.0 , Reward -248.3627242838046 , mean_reward:  -168.6373244156648 , time_score:  108 , memory:  28813
# Episode:  325  , Epsilon:  1.0 , Reward -130.75963539857088 , mean_reward:  -169.4293623743435 , time_score:  78 , memory:  29243
# Episode:  330  , Epsilon:  1.0 , Reward -85.02553252852972 , mean_reward:  -172.6595947164481 , time_score:  65 , memory:  29688
# Episode:  335  , Epsilon:  1.0 , Reward -123.0795057708285 , mean_reward:  -170.50242473153403 , time_score:  63 , memory:  30074
# Episode:  340  , Epsilon:  1.0 , Reward -10.031229368056188 , mean_reward:  -172.60372121716952 , time_score:  79 , memory:  30514
# Episode:  345  , Epsilon:  1.0 , Reward -138.39218655874413 , mean_reward:  -173.3319698317548 , time_score:  66 , memory:  30925
# Episode:  350  , Epsilon:  1.0 , Reward -187.00830654546843 , mean_reward:  -171.36629484485408 , time_score:  113 , memory:  31428
# Episode:  355  , Epsilon:  1.0 , Reward -97.22278023031637 , mean_reward:  -173.31348056871494 , time_score:  66 , memory:  31867
# Episode:  360  , Epsilon:  1.0 , Reward -109.25418884709721 , mean_reward:  -172.01542002328958 , time_score:  85 , memory:  32339
# Episode:  365  , Epsilon:  1.0 , Reward -59.504451923786476 , mean_reward:  -169.44370312216236 , time_score:  65 , memory:  32788
# Episode:  370  , Epsilon:  1.0 , Reward -170.82015009275085 , mean_reward:  -171.18015032281312 , time_score:  134 , memory:  33247
# Episode:  375  , Epsilon:  1.0 , Reward -81.77344496103242 , mean_reward:  -169.80833011249007 , time_score:  73 , memory:  33701
# Episode:  380  , Epsilon:  1.0 , Reward -109.30056926278112 , mean_reward:  -170.7907772608525 , time_score:  65 , memory:  34127
# Episode:  385  , Epsilon:  1.0 , Reward -103.0921210293711 , mean_reward:  -168.691350209942 , time_score:  132 , memory:  34627
# Episode:  390  , Epsilon:  1.0 , Reward -129.5458989599974 , mean_reward:  -167.2562233207517 , time_score:  86 , memory:  35088
# Episode:  395  , Epsilon:  1.0 , Reward -343.20408037865786 , mean_reward:  -170.93460690088082 , time_score:  82 , memory:  35523
# Episode:  400  , Epsilon:  1.0 , Reward -299.34626430056693 , mean_reward:  -174.83456143142863 , time_score:  108 , memory:  36030
# Episode:  405  , Epsilon:  1.0 , Reward -154.88322424655155 , mean_reward:  -179.62574376912116 , time_score:  72 , memory:  36410
# Episode:  410  , Epsilon:  1.0 , Reward -211.66428101939323 , mean_reward:  -184.46891802527588 , time_score:  68 , memory:  36885
# Episode:  415  , Epsilon:  1.0 , Reward -212.24738657685327 , mean_reward:  -188.10632853408498 , time_score:  121 , memory:  37353
# Episode:  420  , Epsilon:  1.0 , Reward -112.33047913007607 , mean_reward:  -187.55660249435468 , time_score:  78 , memory:  37780
# Episode:  425  , Epsilon:  1.0 , Reward -115.91015789906942 , mean_reward:  -183.30744485978744 , time_score:  88 , memory:  38278
# Episode:  430  , Epsilon:  1.0 , Reward -293.38829665100127 , mean_reward:  -180.25567741675917 , time_score:  109 , memory:  38686
# Episode:  435  , Epsilon:  1.0 , Reward -187.5034534535027 , mean_reward:  -182.94160477171215 , time_score:  75 , memory:  39069
# Episode:  440  , Epsilon:  1.0 , Reward -119.91158772780277 , mean_reward:  -180.09235567570082 , time_score:  78 , memory:  39485
# Episode:  445  , Epsilon:  1.0 , Reward -119.51598824730357 , mean_reward:  -181.67024954688523 , time_score:  90 , memory:  39962
# Episode:  450  , Epsilon:  1.0 , Reward -279.3711346449304 , mean_reward:  -188.2556143923986 , time_score:  125 , memory:  40478
# Episode:  455  , Epsilon:  1.0 , Reward -210.7540181396014 , mean_reward:  -190.4664236820495 , time_score:  100 , memory:  40986
# Episode:  460  , Epsilon:  1.0 , Reward -126.83769243166779 , mean_reward:  -191.50008773563266 , time_score:  83 , memory:  41451
# Episode:  465  , Epsilon:  1.0 , Reward -78.41826352586034 , mean_reward:  -194.07812019987585 , time_score:  78 , memory:  41875
# Episode:  470  , Epsilon:  1.0 , Reward -7.589231793826315 , mean_reward:  -190.86289084013396 , time_score:  96 , memory:  42331
# Episode:  475  , Epsilon:  1.0 , Reward -146.803277261807 , mean_reward:  -189.68313138565486 , time_score:  83 , memory:  42763
# Episode:  480  , Epsilon:  1.0 , Reward -297.05460020372914 , mean_reward:  -187.9236929134386 , time_score:  89 , memory:  43206
# Episode:  485  , Epsilon:  1.0 , Reward -232.9978090038153 , mean_reward:  -189.70112488531947 , time_score:  108 , memory:  43665
# Episode:  490  , Epsilon:  1.0 , Reward -112.28996616248077 , mean_reward:  -194.6852190500039 , time_score:  77 , memory:  44173
# Episode:  495  , Epsilon:  1.0 , Reward -26.790156536791542 , mean_reward:  -186.86008177918285 , time_score:  120 , memory:  44618
# Episode:  500  , Epsilon:  1.0 , Reward -267.3647986736057 , mean_reward:  -180.3382547374096 , time_score:  109 , memory:  45079
# Episode:  505  , Epsilon:  1.0 , Reward -273.11078869258665 , mean_reward:  -182.1191189047369 , time_score:  90 , memory:  45550
# Episode:  510  , Epsilon:  1.0 , Reward -265.6387354510338 , mean_reward:  -184.75699954015215 , time_score:  87 , memory:  46112
# Episode:  515  , Epsilon:  1.0 , Reward -134.4665528624368 , mean_reward:  -180.89258334912435 , time_score:  88 , memory:  46598
# Episode:  520  , Epsilon:  1.0 , Reward -134.66697868069664 , mean_reward:  -181.98411142734597 , time_score:  118 , memory:  47114
# Episode:  525  , Epsilon:  1.0 , Reward -68.94107967576251 , mean_reward:  -183.0863968063376 , time_score:  69 , memory:  47539
# Episode:  530  , Epsilon:  1.0 , Reward -113.27026934167102 , mean_reward:  -184.93700521859492 , time_score:  110 , memory:  47996
# Episode:  535  , Epsilon:  1.0 , Reward -101.75958194003863 , mean_reward:  -179.83924897939113 , time_score:  95 , memory:  48436
# Episode:  540  , Epsilon:  1.0 , Reward -244.11777699755538 , mean_reward:  -182.80357719971929 , time_score:  94 , memory:  48848
# Episode:  545  , Epsilon:  1.0 , Reward -121.42597427779435 , mean_reward:  -178.62041448553384 , time_score:  92 , memory:  49630
# Episode:  550  , Epsilon:  1.0 , Reward -271.4402352991234 , mean_reward:  -174.21333894265695 , time_score:  107 , memory:  50148
# Episode:  555  , Epsilon:  1.0 , Reward -129.54839001636606 , mean_reward:  -168.5680841084194 , time_score:  67 , memory:  50591
# Episode:  560  , Epsilon:  1.0 , Reward -119.8603936587004 , mean_reward:  -170.01058179941967 , time_score:  85 , memory:  50968
# Episode:  565  , Epsilon:  1.0 , Reward -69.70835129833827 , mean_reward:  -170.13349747542475 , time_score:  71 , memory:  51440
# Episode:  570  , Epsilon:  1.0 , Reward -158.25966288449422 , mean_reward:  -181.66317951559606 , time_score:  96 , memory:  51979
# Episode:  575  , Epsilon:  1.0 , Reward -38.91026866034467 , mean_reward:  -185.0361454090997 , time_score:  98 , memory:  52460
# Episode:  580  , Epsilon:  1.0 , Reward -234.1548596089158 , mean_reward:  -188.09456163163807 , time_score:  106 , memory:  52901
# Episode:  585  , Epsilon:  1.0 , Reward -177.52186763677264 , mean_reward:  -186.49367859194626 , time_score:  141 , memory:  53459
# Episode:  590  , Epsilon:  1.0 , Reward -87.02081545238484 , mean_reward:  -183.72549813883788 , time_score:  84 , memory:  53918
# Episode:  595  , Epsilon:  1.0 , Reward -142.61935034828156 , mean_reward:  -186.41390878123454 , time_score:  97 , memory:  54316
# Episode:  600  , Epsilon:  1.0 , Reward -105.4607842083604 , mean_reward:  -188.82734192515613 , time_score:  64 , memory:  54733
# Episode:  605  , Epsilon:  1.0 , Reward -281.18900577072566 , mean_reward:  -190.23005288240486 , time_score:  98 , memory:  55232
# Episode:  610  , Epsilon:  1.0 , Reward -81.48991862632872 , mean_reward:  -182.92352343318404 , time_score:  83 , memory:  55623
# Episode:  615  , Epsilon:  1.0 , Reward -109.59620757403087 , mean_reward:  -183.04814378103816 , time_score:  59 , memory:  56003
# Episode:  620  , Epsilon:  1.0 , Reward -160.20342765214087 , mean_reward:  -187.954644324381 , time_score:  108 , memory:  56527
# Episode:  625  , Epsilon:  1.0 , Reward -281.2768101448265 , mean_reward:  -189.3911357498277 , time_score:  92 , memory:  56916
# Episode:  630  , Epsilon:  1.0 , Reward -389.7412161724659 , mean_reward:  -189.7744858117533 , time_score:  97 , memory:  57429
# Episode:  635  , Epsilon:  1.0 , Reward -302.06760549845325 , mean_reward:  -200.58895706374497 , time_score:  112 , memory:  57857
# Episode:  640  , Epsilon:  1.0 , Reward -231.48076587545717 , mean_reward:  -206.96699250097447 , time_score:  109 , memory:  58285
# Episode:  645  , Epsilon:  1.0 , Reward -50.596817361783636 , mean_reward:  -210.2870790847372 , time_score:  79 , memory:  58653
# Episode:  650  , Epsilon:  1.0 , Reward -53.479039167975046 , mean_reward:  -207.9827447825321 , time_score:  62 , memory:  59170
# Episode:  655  , Epsilon:  1.0 , Reward -385.50062249005174 , mean_reward:  -209.9059962017276 , time_score:  111 , memory:  59633
# Episode:  660  , Epsilon:  1.0 , Reward -340.65909162100127 , mean_reward:  -209.79397776980954 , time_score:  97 , memory:  60078
# Episode:  665  , Epsilon:  1.0 , Reward -339.68896288875516 , mean_reward:  -209.92447284897943 , time_score:  105 , memory:  60532
# Episode:  670  , Epsilon:  1.0 , Reward -131.5138661911429 , mean_reward:  -205.18846259346222 , time_score:  117 , memory:  61048
# Episode:  675  , Epsilon:  1.0 , Reward -104.19464732192691 , mean_reward:  -203.798579896896 , time_score:  116 , memory:  61560
# Episode:  680  , Epsilon:  1.0 , Reward -0.23115011158884613 , mean_reward:  -200.49865724934182 , time_score:  68 , memory:  61974
# Episode:  685  , Epsilon:  1.0 , Reward -132.9648478219886 , mean_reward:  -203.14600665580886 , time_score:  77 , memory:  62427
# Episode:  690  , Epsilon:  1.0 , Reward -299.5742690913042 , mean_reward:  -201.79772150240325 , time_score:  104 , memory:  62927
# Episode:  695  , Epsilon:  1.0 , Reward -119.14069089711965 , mean_reward:  -199.35069016542093 , time_score:  108 , memory:  63389
# Episode:  700  , Epsilon:  1.0 , Reward -190.6820828284806 , mean_reward:  -198.31562013894 , time_score:  99 , memory:  63824
# Episode:  705  , Epsilon:  1.0 , Reward -279.1546197031225 , mean_reward:  -194.6137228089862 , time_score:  91 , memory:  64247
# Episode:  710  , Epsilon:  1.0 , Reward -224.03664898898356 , mean_reward:  -196.5526262653327 , time_score:  81 , memory:  64676
# Episode:  715  , Epsilon:  1.0 , Reward -164.59837948767935 , mean_reward:  -196.747532626931 , time_score:  91 , memory:  65136
# Episode:  720  , Epsilon:  1.0 , Reward -157.2864929142653 , mean_reward:  -195.2474316276356 , time_score:  103 , memory:  65593
# Episode:  725  , Epsilon:  1.0 , Reward -325.8998192093479 , mean_reward:  -199.10460743510114 , time_score:  120 , memory:  66081
# Episode:  730  , Epsilon:  1.0 , Reward -203.471820898381 , mean_reward:  -196.89965326186677 , time_score:  91 , memory:  66473
# Episode:  735  , Epsilon:  1.0 , Reward -181.260776796002 , mean_reward:  -187.58046059741605 , time_score:  99 , memory:  66848
# Episode:  740  , Epsilon:  1.0 , Reward -99.63561897373714 , mean_reward:  -179.85542931953864 , time_score:  108 , memory:  67237
# Episode:  745  , Epsilon:  1.0 , Reward -383.12494203008026 , mean_reward:  -185.26580241389019 , time_score:  123 , memory:  67740
# Episode:  750  , Epsilon:  1.0 , Reward -73.38748171540875 , mean_reward:  -182.83742732480704 , time_score:  75 , memory:  68125
# Episode:  755  , Epsilon:  1.0 , Reward -111.78886999614119 , mean_reward:  -188.5264309782233 , time_score:  81 , memory:  68586
# Episode:  760  , Epsilon:  1.0 , Reward -141.9874753980599 , mean_reward:  -195.4393629483216 , time_score:  143 , memory:  69106
# Episode:  765  , Epsilon:  1.0 , Reward -200.96090287089797 , mean_reward:  -192.98862905816787 , time_score:  91 , memory:  69588
# Episode:  770  , Epsilon:  1.0 , Reward -242.3117453879699 , mean_reward:  -189.68725511330808 , time_score:  81 , memory:  70009
# Episode:  775  , Epsilon:  1.0 , Reward -121.60650063151924 , mean_reward:  -189.16385046504266 , time_score:  62 , memory:  70483
# Episode:  780  , Epsilon:  1.0 , Reward -399.003326816144 , mean_reward:  -192.89450496700655 , time_score:  116 , memory:  71022
# Episode:  785  , Epsilon:  1.0 , Reward -96.3472923048289 , mean_reward:  -190.56631280881894 , time_score:  115 , memory:  71500
# Episode:  790  , Epsilon:  1.0 , Reward -263.7881283498589 , mean_reward:  -191.4334972661991 , time_score:  77 , memory:  71881
# Episode:  795  , Epsilon:  1.0 , Reward -132.90156686705393 , mean_reward:  -194.1752794346928 , time_score:  115 , memory:  72379
# Episode:  800  , Epsilon:  1.0 , Reward -414.5522847296032 , mean_reward:  -197.948329574378 , time_score:  120 , memory:  72849
# Episode:  805  , Epsilon:  1.0 , Reward -101.69812689340509 , mean_reward:  -199.0597926525959 , time_score:  87 , memory:  73309
# Episode:  810  , Epsilon:  1.0 , Reward -321.5746141798406 , mean_reward:  -199.82554307824884 , time_score:  120 , memory:  73774
# Episode:  815  , Epsilon:  1.0 , Reward -162.6151867248219 , mean_reward:  -198.425988046775 , time_score:  122 , memory:  74265
# Episode:  820  , Epsilon:  1.0 , Reward -199.24590626424157 , mean_reward:  -194.82906603824986 , time_score:  109 , memory:  74831
# Episode:  825  , Epsilon:  1.0 , Reward -127.62623680006058 , mean_reward:  -191.04006375176053 , time_score:  107 , memory:  75299
# Episode:  830  , Epsilon:  1.0 , Reward -70.45126096731583 , mean_reward:  -189.94386137972512 , time_score:  68 , memory:  75758
# Episode:  835  , Epsilon:  1.0 , Reward -169.04200954630863 , mean_reward:  -191.36214587279494 , time_score:  119 , memory:  76214
# Episode:  840  , Epsilon:  1.0 , Reward 25.908094887086875 , mean_reward:  -192.84034139615898 , time_score:  104 , memory:  76649
# Episode:  845  , Epsilon:  1.0 , Reward -221.27114637901923 , mean_reward:  -191.41727673915935 , time_score:  101 , memory:  77184
# Episode:  850  , Epsilon:  1.0 , Reward -69.32102682412574 , mean_reward:  -191.99511723933185 , time_score:  76 , memory:  77606
# Episode:  855  , Epsilon:  1.0 , Reward -78.45889151278865 , mean_reward:  -184.5440427520534 , time_score:  106 , memory:  78033
# Episode:  860  , Epsilon:  1.0 , Reward -226.83988281658503 , mean_reward:  -177.12839845836442 , time_score:  72 , memory:  78438
# Episode:  865  , Epsilon:  1.0 , Reward -308.9701542850837 , mean_reward:  -177.81860175258691 , time_score:  89 , memory:  78867
# Episode:  870  , Epsilon:  1.0 , Reward -183.7031624485147 , mean_reward:  -173.76943885946315 , time_score:  69 , memory:  79245
# Episode:  875  , Epsilon:  1.0 , Reward -97.85444596715956 , mean_reward:  -169.54873529247553 , time_score:  110 , memory:  80150
# Episode:  880  , Epsilon:  1.0 , Reward -89.16273811700579 , mean_reward:  -163.97237088800358 , time_score:  62 , memory:  80575
# Episode:  885  , Epsilon:  1.0 , Reward -24.971667122336797 , mean_reward:  -168.55553568923176 , time_score:  103 , memory:  81087
# Episode:  890  , Epsilon:  1.0 , Reward -39.5680557828901 , mean_reward:  -162.674755138675 , time_score:  69 , memory:  81566
# Episode:  895  , Epsilon:  1.0 , Reward -105.200656569303 , mean_reward:  -163.28148687701255 , time_score:  78 , memory:  81962
# Episode:  900  , Epsilon:  1.0 , Reward -137.6356478888776 , mean_reward:  -160.1682952200608 , time_score:  94 , memory:  82409
# Episode:  905  , Epsilon:  1.0 , Reward -116.2228028364654 , mean_reward:  -156.07508024454893 , time_score:  108 , memory:  82811
# Episode:  910  , Epsilon:  1.0 , Reward 8.90412392590251 , mean_reward:  -150.16207903500901 , time_score:  77 , memory:  83203
# Episode:  915  , Epsilon:  1.0 , Reward -131.70694733431773 , mean_reward:  -153.26501514560425 , time_score:  68 , memory:  83643
# Episode:  920  , Epsilon:  1.0 , Reward -216.971378732476 , mean_reward:  -153.42000949196995 , time_score:  69 , memory:  84022
# Episode:  925  , Epsilon:  1.0 , Reward -408.60627924677834 , mean_reward:  -154.06429199236777 , time_score:  80 , memory:  84429
# Episode:  930  , Epsilon:  1.0 , Reward -127.81540875430692 , mean_reward:  -159.53521595971213 , time_score:  89 , memory:  84888
# Episode:  935  , Epsilon:  1.0 , Reward -351.09445117711925 , mean_reward:  -161.71325013035602 , time_score:  104 , memory:  85326
# Episode:  940  , Epsilon:  1.0 , Reward -238.88887224744985 , mean_reward:  -160.3162612090349 , time_score:  111 , memory:  85799
# Episode:  945  , Epsilon:  1.0 , Reward -146.32645272801548 , mean_reward:  -157.9324376281939 , time_score:  92 , memory:  86279
# Episode:  950  , Epsilon:  1.0 , Reward -134.8934575751034 , mean_reward:  -160.39453414030717 , time_score:  76 , memory:  86728
# Episode:  955  , Epsilon:  1.0 , Reward -243.78331150250725 , mean_reward:  -164.80177013891665 , time_score:  103 , memory:  87236
# Episode:  960  , Epsilon:  1.0 , Reward -103.44413760856878 , mean_reward:  -163.3330937694869 , time_score:  74 , memory:  87678
# Episode:  965  , Epsilon:  1.0 , Reward -208.67527029873457 , mean_reward:  -167.43114131581942 , time_score:  104 , memory:  88193
# Episode:  970  , Epsilon:  1.0 , Reward -75.62723178124342 , mean_reward:  -170.195080168974 , time_score:  85 , memory:  88618
# Episode:  975  , Epsilon:  1.0 , Reward -98.90096040924351 , mean_reward:  -172.51424499839533 , time_score:  60 , memory:  89023
# Episode:  980  , Epsilon:  1.0 , Reward -333.2694473545614 , mean_reward:  -178.05083448199898 , time_score:  95 , memory:  89505
# Episode:  985  , Epsilon:  1.0 , Reward -247.33295986225139 , mean_reward:  -178.51293307109168 , time_score:  127 , memory:  90098
# Episode:  990  , Epsilon:  1.0 , Reward -101.56002430975421 , mean_reward:  -181.18532948845495 , time_score:  129 , memory:  90589
# Episode:  995  , Epsilon:  1.0 , Reward -196.96311245975141 , mean_reward:  -179.07657400419572 , time_score:  86 , memory:  91137
# Episode:  1000  , Epsilon:  1.0 , Reward -140.30782712978143 , mean_reward:  -176.9490954887975 , time_score:  75 , memory:  91624
# Episode:  1005  , Epsilon:  1.0 , Reward -224.14440164857172 , mean_reward:  -182.9833609616908 , time_score:  133 , memory:  92138
# Episode:  1010  , Epsilon:  1.0 , Reward -99.76620805026708 , mean_reward:  -187.00360916548743 , time_score:  62 , memory:  92566
# Episode:  1015  , Epsilon:  1.0 , Reward -100.68324529551187 , mean_reward:  -181.3465978251838 , time_score:  68 , memory:  92982
# Episode:  1020  , Epsilon:  1.0 , Reward -131.60446606747837 , mean_reward:  -180.7321985723637 , time_score:  107 , memory:  93423
# Episode:  1025  , Epsilon:  1.0 , Reward -49.145511747732506 , mean_reward:  -178.4318296257405 , time_score:  66 , memory:  93831
# Episode:  1030  , Epsilon:  1.0 , Reward -350.9475051870901 , mean_reward:  -178.32092638421483 , time_score:  108 , memory:  94359
# Episode:  1035  , Epsilon:  1.0 , Reward -30.677445245836125 , mean_reward:  -175.2333008140011 , time_score:  81 , memory:  94814
# Episode:  1040  , Epsilon:  1.0 , Reward -243.2848042640894 , mean_reward:  -174.57671519731437 , time_score:  86 , memory:  95213
# Episode:  1045  , Epsilon:  1.0 , Reward -140.305321665671 , mean_reward:  -177.13743851047494 , time_score:  77 , memory:  95733
# Episode:  1050  , Epsilon:  1.0 , Reward -131.0780331189466 , mean_reward:  -179.65915982706673 , time_score:  87 , memory:  96208
# Episode:  1055  , Epsilon:  1.0 , Reward -385.06676580862626 , mean_reward:  -182.27146284921164 , time_score:  100 , memory:  96679
# Episode:  1060  , Epsilon:  1.0 , Reward -72.95090419553897 , mean_reward:  -179.75456202108433 , time_score:  60 , memory:  97005
# Episode:  1065  , Epsilon:  1.0 , Reward -220.89826840606972 , mean_reward:  -175.4535292722886 , time_score:  123 , memory:  97480
# Episode:  1070  , Epsilon:  1.0 , Reward -77.4204986169728 , mean_reward:  -175.49677990037216 , time_score:  82 , memory:  97937
# Episode:  1075  , Epsilon:  1.0 , Reward -113.33917456657137 , mean_reward:  -174.2248873234656 , time_score:  83 , memory:  98369
# Episode:  1080  , Epsilon:  1.0 , Reward -94.45233749198178 , mean_reward:  -170.01999631435373 , time_score:  61 , memory:  98742
# Episode:  1085  , Epsilon:  1.0 , Reward -440.6332564988727 , mean_reward:  -175.36797899985672 , time_score:  131 , memory:  99233
# Episode:  1090  , Epsilon:  1.0 , Reward -215.78880483900275 , mean_reward:  -176.40469681419242 , time_score:  136 , memory:  99721
# Episode:  1095  , Epsilon:  1.0 , Reward -185.8758347146666 , mean_reward:  -178.36301438394696 , time_score:  125 , memory:  100192
# Episode:  1100  , Epsilon:  1.0 , Reward -451.4927127027692 , mean_reward:  -183.54611101158048 , time_score:  99 , memory:  100647
# Episode:  1105  , Epsilon:  1.0 , Reward -179.24987972960776 , mean_reward:  -180.13365547341562 , time_score:  87 , memory:  101159
# Episode:  1110  , Epsilon:  1.0 , Reward -282.56284914323965 , mean_reward:  -183.8702053893315 , time_score:  109 , memory:  101623
# Episode:  1115  , Epsilon:  1.0 , Reward -225.58752013038875 , mean_reward:  -186.2592630619408 , time_score:  72 , memory:  102029
# Episode:  1120  , Epsilon:  1.0 , Reward -171.89292837990297 , mean_reward:  -184.55020764613232 , time_score:  115 , memory:  102465
# Episode:  1125  , Epsilon:  1.0 , Reward -97.98894927879208 , mean_reward:  -182.15932716132878 , time_score:  75 , memory:  102861
# Episode:  1130  , Epsilon:  1.0 , Reward -244.1981437172324 , mean_reward:  -180.5131945585854 , time_score:  95 , memory:  103361
# Episode:  1135  , Epsilon:  1.0 , Reward -148.47909949169298 , mean_reward:  -183.38527277569273 , time_score:  61 , memory:  103841
# Episode:  1140  , Epsilon:  1.0 , Reward -151.64038996345062 , mean_reward:  -185.28398033565034 , time_score:  69 , memory:  104260
# Episode:  1145  , Epsilon:  1.0 , Reward -141.19560589322842 , mean_reward:  -184.58137504991166 , time_score:  82 , memory:  104796
# Episode:  1150  , Epsilon:  1.0 , Reward -55.956569203613306 , mean_reward:  -177.3341462320625 , time_score:  59 , memory:  105195
# Episode:  1155  , Epsilon:  1.0 , Reward -385.46998756246217 , mean_reward:  -175.28176835806664 , time_score:  101 , memory:  105634
# Episode:  1160  , Epsilon:  1.0 , Reward -91.68042195622449 , mean_reward:  -179.70330135955442 , time_score:  68 , memory:  106095
# Episode:  1165  , Epsilon:  1.0 , Reward -62.77125736516603 , mean_reward:  -178.1102484571725 , time_score:  108 , memory:  106599
# Episode:  1170  , Epsilon:  1.0 , Reward -321.20322008273604 , mean_reward:  -183.02888295252987 , time_score:  122 , memory:  107080
# Episode:  1175  , Epsilon:  1.0 , Reward -124.02487684751233 , mean_reward:  -183.180812895213 , time_score:  79 , memory:  107438
# Episode:  1180  , Epsilon:  1.0 , Reward -117.25079505194124 , mean_reward:  -182.1807358644589 , time_score:  89 , memory:  107898
# Episode:  1185  , Epsilon:  1.0 , Reward -278.5085276640226 , mean_reward:  -174.6015634948062 , time_score:  85 , memory:  108318
# Episode:  1190  , Epsilon:  1.0 , Reward -123.0230675733705 , mean_reward:  -170.919057604366 , time_score:  104 , memory:  108755
# Episode:  1195  , Epsilon:  1.0 , Reward -497.53898276523756 , mean_reward:  -175.12180027005692 , time_score:  119 , memory:  109287
# Episode:  1200  , Epsilon:  1.0 , Reward -111.52942028779144 , mean_reward:  -170.65194840001513 , time_score:  73 , memory:  109763
# Episode:  1205  , Epsilon:  1.0 , Reward -111.46180846897624 , mean_reward:  -166.75558130524468 , time_score:  130 , memory:  110230
# Episode:  1210  , Epsilon:  1.0 , Reward -192.41587853060074 , mean_reward:  -164.32038248026169 , time_score:  108 , memory:  110736
# Episode:  1215  , Epsilon:  1.0 , Reward -122.90075274506188 , mean_reward:  -164.4540744665583 , time_score:  77 , memory:  111179
# Episode:  1220  , Epsilon:  1.0 , Reward -102.4394136908297 , mean_reward:  -167.84565382690508 , time_score:  57 , memory:  111596
# Episode:  1225  , Epsilon:  1.0 , Reward -421.6305868956641 , mean_reward:  -176.26410330607607 , time_score:  86 , memory:  112081
# Episode:  1230  , Epsilon:  1.0 , Reward -337.00875508480414 , mean_reward:  -175.87730688603554 , time_score:  85 , memory:  112563
# Episode:  1235  , Epsilon:  1.0 , Reward -109.43724915503105 , mean_reward:  -178.04984578159466 , time_score:  103 , memory:  113092
# Episode:  1240  , Epsilon:  1.0 , Reward -69.33367327950698 , mean_reward:  -177.9063936442073 , time_score:  78 , memory:  113561
# Episode:  1245  , Epsilon:  1.0 , Reward -100.08520673632239 , mean_reward:  -175.12371303243472 , time_score:  65 , memory:  113934
# Episode:  1250  , Epsilon:  1.0 , Reward -176.94327377205883 , mean_reward:  -179.89937086576904 , time_score:  67 , memory:  114296
# Episode:  1255  , Epsilon:  1.0 , Reward -81.37517185197476 , mean_reward:  -180.56145468986827 , time_score:  103 , memory:  114784
# Episode:  1260  , Epsilon:  1.0 , Reward -107.57674120699001 , mean_reward:  -181.33609491874006 , time_score:  84 , memory:  115285
# Episode:  1265  , Epsilon:  1.0 , Reward -65.00008455904924 , mean_reward:  -185.13518844997884 , time_score:  114 , memory:  115809
# Episode:  1270  , Epsilon:  1.0 , Reward -105.68451191392373 , mean_reward:  -178.17736131268833 , time_score:  60 , memory:  116164
# Episode:  1275  , Epsilon:  1.0 , Reward -113.65736208675017 , mean_reward:  -181.1871799492819 , time_score:  151 , memory:  116686
# Episode:  1280  , Epsilon:  1.0 , Reward -180.2076506388748 , mean_reward:  -180.82929473027212 , time_score:  119 , memory:  117210
# Episode:  1285  , Epsilon:  1.0 , Reward -174.3233531613448 , mean_reward:  -178.97870842926048 , time_score:  133 , memory:  117780
# Episode:  1290  , Epsilon:  1.0 , Reward -149.11056830776107 , mean_reward:  -185.50889514701402 , time_score:  98 , memory:  118232
# Episode:  1295  , Epsilon:  1.0 , Reward -82.45604465568242 , mean_reward:  -179.1262021644705 , time_score:  92 , memory:  118724
# Episode:  1300  , Epsilon:  1.0 , Reward -124.2935650180524 , mean_reward:  -181.9535629700731 , time_score:  72 , memory:  119085
# Episode:  1305  , Epsilon:  1.0 , Reward -121.5938893323722 , mean_reward:  -186.59412373402148 , time_score:  98 , memory:  119622
# Episode:  1310  , Epsilon:  1.0 , Reward -339.85673541821905 , mean_reward:  -189.6555379107105 , time_score:  114 , memory:  120090
# Episode:  1315  , Epsilon:  1.0 , Reward -150.85118523513634 , mean_reward:  -187.91353900146763 , time_score:  97 , memory:  120500
# Episode:  1320  , Epsilon:  1.0 , Reward -302.91378308892683 , mean_reward:  -191.5833420581277 , time_score:  78 , memory:  121020
# Episode:  1325  , Epsilon:  1.0 , Reward -105.69181328392196 , mean_reward:  -189.165934071263 , time_score:  90 , memory:  121489
# Episode:  1330  , Epsilon:  1.0 , Reward -299.07780851290397 , mean_reward:  -189.3677615882828 , time_score:  89 , memory:  121915
# Episode:  1335  , Epsilon:  1.0 , Reward -28.5264572461993 , mean_reward:  -186.05755981018225 , time_score:  89 , memory:  122294
# Episode:  1340  , Epsilon:  1.0 , Reward -175.41999458252764 , mean_reward:  -183.93522130970194 , time_score:  100 , memory:  122786
# Episode:  1345  , Epsilon:  1.0 , Reward -131.01066050837815 , mean_reward:  -182.39393737592465 , time_score:  70 , memory:  123256
# Episode:  1350  , Epsilon:  1.0 , Reward -91.25490166426583 , mean_reward:  -179.9873312357838 , time_score:  98 , memory:  123708
# Episode:  1355  , Epsilon:  1.0 , Reward -79.19087074270365 , mean_reward:  -179.59673530684512 , time_score:  67 , memory:  124139
# Episode:  1360  , Epsilon:  1.0 , Reward -467.3117972922944 , mean_reward:  -180.92941613596497 , time_score:  95 , memory:  124624
# Episode:  1365  , Epsilon:  1.0 , Reward -84.28169714636932 , mean_reward:  -180.71185263551328 , time_score:  82 , memory:  125033
# Episode:  1370  , Epsilon:  1.0 , Reward -159.57137075425723 , mean_reward:  -182.59713737068415 , time_score:  89 , memory:  125467
# Episode:  1375  , Epsilon:  1.0 , Reward -95.07594608100203 , mean_reward:  -179.01064060265747 , time_score:  58 , memory:  125857
# Episode:  1380  , Epsilon:  1.0 , Reward -10.86726452893005 , mean_reward:  -180.64465580566915 , time_score:  95 , memory:  126366
# Episode:  1385  , Epsilon:  1.0 , Reward -119.68703350072991 , mean_reward:  -179.1665351414244 , time_score:  93 , memory:  126858
# Episode:  1390  , Epsilon:  1.0 , Reward -258.6196520849426 , mean_reward:  -179.0823948702633 , time_score:  104 , memory:  127303
# Episode:  1395  , Epsilon:  1.0 , Reward -384.81021087460664 , mean_reward:  -182.4845105972377 , time_score:  84 , memory:  127775
# Episode:  1400  , Epsilon:  1.0 , Reward -107.26353724849173 , mean_reward:  -182.0706195267611 , time_score:  97 , memory:  128296
# Episode:  1405  , Epsilon:  1.0 , Reward -112.42003481899543 , mean_reward:  -184.5118114697877 , time_score:  86 , memory:  128810
# Episode:  1410  , Epsilon:  1.0 , Reward -396.62415677132185 , mean_reward:  -187.58421102977755 , time_score:  91 , memory:  129269
# Episode:  1415  , Epsilon:  1.0 , Reward -268.6334693250777 , mean_reward:  -192.11124197300234 , time_score:  113 , memory:  129777
# Episode:  1420  , Epsilon:  1.0 , Reward -462.1238596776622 , mean_reward:  -189.24246340796083 , time_score:  99 , memory:  130254
# Episode:  1425  , Epsilon:  1.0 , Reward -58.805306899711034 , mean_reward:  -190.41645037530208 , time_score:  71 , memory:  130680
# Episode:  1430  , Epsilon:  1.0 , Reward -134.9655598650141 , mean_reward:  -189.95033312471227 , time_score:  106 , memory:  131200
# Episode:  1435  , Epsilon:  1.0 , Reward -101.07730907729636 , mean_reward:  -193.70141519195465 , time_score:  61 , memory:  131620
# Episode:  1440  , Epsilon:  1.0 , Reward -187.7903995938501 , mean_reward:  -200.90445987675125 , time_score:  101 , memory:  132070
# Episode:  1445  , Epsilon:  1.0 , Reward -195.09651653680015 , mean_reward:  -199.9052017807179 , time_score:  82 , memory:  132503
# Episode:  1450  , Epsilon:  1.0 , Reward -122.49689884494461 , mean_reward:  -206.2653756057667 , time_score:  101 , memory:  132952
# Episode:  1455  , Epsilon:  1.0 , Reward -111.03763368608917 , mean_reward:  -202.5393474990462 , time_score:  113 , memory:  133406
# Episode:  1460  , Epsilon:  1.0 , Reward -219.04784627202613 , mean_reward:  -199.2151259310487 , time_score:  114 , memory:  133885
# Episode:  1465  , Epsilon:  1.0 , Reward -179.3072038585505 , mean_reward:  -195.96938272688195 , time_score:  72 , memory:  134320
# Episode:  1470  , Epsilon:  1.0 , Reward -163.14078965523623 , mean_reward:  -201.04486653005745 , time_score:  107 , memory:  134756
# Episode:  1475  , Epsilon:  1.0 , Reward -98.45461209677188 , mean_reward:  -200.92783061579118 , time_score:  55 , memory:  135205
# Episode:  1480  , Epsilon:  1.0 , Reward -123.91419374949174 , mean_reward:  -202.88487048092534 , time_score:  114 , memory:  135686
# Episode:  1485  , Epsilon:  1.0 , Reward -281.9504296643323 , mean_reward:  -205.51478126460097 , time_score:  83 , memory:  136172
# Episode:  1490  , Epsilon:  1.0 , Reward -99.42010441173396 , mean_reward:  -205.99258771412173 , time_score:  63 , memory:  136584
# Episode:  1495  , Epsilon:  1.0 , Reward -173.95977902334405 , mean_reward:  -205.5965519279434 , time_score:  118 , memory:  137069
# Episode:  1500  , Epsilon:  1.0 , Reward -83.2160732661662 , mean_reward:  -208.62375000015595 , time_score:  116 , memory:  137505
# Episode:  1505  , Epsilon:  1.0 , Reward -98.8918479529397 , mean_reward:  -203.835871643543 , time_score:  83 , memory:  137931
# Episode:  1510  , Epsilon:  1.0 , Reward -202.30717333456914 , mean_reward:  -194.22617823979007 , time_score:  71 , memory:  138345
# Episode:  1515  , Epsilon:  1.0 , Reward -114.95515461720856 , mean_reward:  -191.45462175593119 , time_score:  79 , memory:  138778
# Episode:  1520  , Epsilon:  1.0 , Reward -127.80993100897307 , mean_reward:  -191.9716517412817 , time_score:  92 , memory:  139256
# Episode:  1525  , Epsilon:  1.0 , Reward -142.3961588653809 , mean_reward:  -189.70693932048974 , time_score:  121 , memory:  139740
# Episode:  1530  , Epsilon:  1.0 , Reward -108.11564510746618 , mean_reward:  -186.79591730824148 , time_score:  69 , memory:  140215
# Episode:  1535  , Epsilon:  1.0 , Reward -286.5269401549609 , mean_reward:  -182.94705246391445 , time_score:  93 , memory:  140625
# Episode:  1540  , Epsilon:  1.0 , Reward -119.96943027474165 , mean_reward:  -176.73255347882542 , time_score:  93 , memory:  141152
# Episode:  1545  , Epsilon:  1.0 , Reward -86.2274730189589 , mean_reward:  -183.39865460353457 , time_score:  69 , memory:  141565
# Episode:  1550  , Epsilon:  1.0 , Reward -250.16346524773914 , mean_reward:  -176.41620381582442 , time_score:  71 , memory:  141991
# Episode:  1555  , Epsilon:  1.0 , Reward -126.53940160499599 , mean_reward:  -177.82515556249615 , time_score:  92 , memory:  142406
# Episode:  1560  , Epsilon:  1.0 , Reward -171.35313376328477 , mean_reward:  -179.80547812813572 , time_score:  68 , memory:  142818
# Episode:  1565  , Epsilon:  1.0 , Reward -105.32343819457292 , mean_reward:  -178.00454473491615 , time_score:  116 , memory:  143268
# Episode:  1570  , Epsilon:  1.0 , Reward -88.97424606509789 , mean_reward:  -170.538248206445 , time_score:  68 , memory:  143677
# Episode:  1575  , Epsilon:  1.0 , Reward -107.85934470846065 , mean_reward:  -170.25386428009296 , time_score:  90 , memory:  144174
# Episode:  1580  , Epsilon:  1.0 , Reward -185.07691561029827 , mean_reward:  -168.10087472092255 , time_score:  85 , memory:  144620
# Episode:  1585  , Epsilon:  1.0 , Reward -118.09961704252089 , mean_reward:  -171.35754653506928 , time_score:  103 , memory:  145099
# Episode:  1590  , Epsilon:  1.0 , Reward -189.61793916487449 , mean_reward:  -170.11446273032405 , time_score:  102 , memory:  145610
# Episode:  1595  , Epsilon:  1.0 , Reward -76.95786829797558 , mean_reward:  -166.41898971772775 , time_score:  116 , memory:  146163
# Episode:  1600  , Epsilon:  1.0 , Reward -181.27556571582284 , mean_reward:  -162.46853532952656 , time_score:  137 , memory:  146658
# Episode:  1605  , Epsilon:  1.0 , Reward -99.51591832183348 , mean_reward:  -162.24555433723884 , time_score:  67 , memory:  147072
# Episode:  1610  , Epsilon:  1.0 , Reward -159.7295949117124 , mean_reward:  -164.91090555515012 , time_score:  70 , memory:  147501
# Episode:  1615  , Epsilon:  1.0 , Reward -39.10070231290376 , mean_reward:  -165.69381834619537 , time_score:  101 , memory:  148044
# Episode:  1620  , Epsilon:  1.0 , Reward -338.14817952685905 , mean_reward:  -164.63261965251434 , time_score:  86 , memory:  148472
# Episode:  1625  , Epsilon:  1.0 , Reward -136.22710139787932 , mean_reward:  -165.42801853331719 , time_score:  76 , memory:  148973
# Episode:  1630  , Epsilon:  1.0 , Reward -136.50594239943257 , mean_reward:  -167.02882547635932 , time_score:  100 , memory:  149502
# Episode:  1635  , Epsilon:  1.0 , Reward -91.41434721362256 , mean_reward:  -168.9204929621201 , time_score:  63 , memory:  149991
# Episode:  1640  , Epsilon:  1.0 , Reward -123.11042827641037 , mean_reward:  -171.39788996381242 , time_score:  79 , memory:  150453
# Episode:  1645  , Epsilon:  1.0 , Reward -191.53808106839466 , mean_reward:  -169.09008529051712 , time_score:  73 , memory:  150901
# Episode:  1650  , Epsilon:  1.0 , Reward -270.63988443878634 , mean_reward:  -173.1467767563403 , time_score:  81 , memory:  151380
# Episode:  1655  , Epsilon:  1.0 , Reward -519.4994935439804 , mean_reward:  -181.24164238541272 , time_score:  116 , memory:  151872
# Episode:  1660  , Epsilon:  1.0 , Reward -230.76427451805782 , mean_reward:  -185.30920547107496 , time_score:  108 , memory:  152346
# Episode:  1665  , Epsilon:  1.0 , Reward -96.53213117979364 , mean_reward:  -194.10795408122377 , time_score:  81 , memory:  152830
# Episode:  1670  , Epsilon:  1.0 , Reward -412.2509241258159 , mean_reward:  -196.59358962651524 , time_score:  117 , memory:  153286
# Episode:  1675  , Epsilon:  1.0 , Reward -86.2003579378538 , mean_reward:  -195.08096533448733 , time_score:  69 , memory:  153831
# Episode:  1680  , Epsilon:  1.0 , Reward -219.56164336078353 , mean_reward:  -194.8159595442563 , time_score:  71 , memory:  154227
# Episode:  1685  , Epsilon:  1.0 , Reward -103.06974895076488 , mean_reward:  -195.67148583943865 , time_score:  106 , memory:  154788
# Episode:  1690  , Epsilon:  1.0 , Reward -84.47012394791524 , mean_reward:  -193.36910454998832 , time_score:  69 , memory:  155141
# Episode:  1695  , Epsilon:  1.0 , Reward -162.3195427436625 , mean_reward:  -199.4943802357406 , time_score:  101 , memory:  155622
# Episode:  1700  , Epsilon:  1.0 , Reward -185.04255718061128 , mean_reward:  -196.24491384948192 , time_score:  115 , memory:  156059
# Episode:  1705  , Epsilon:  1.0 , Reward -37.26232628435058 , mean_reward:  -194.1981180640223 , time_score:  82 , memory:  156448
# Episode:  1710  , Epsilon:  1.0 , Reward -389.4394197356928 , mean_reward:  -196.27123941631945 , time_score:  106 , memory:  156851
# Episode:  1715  , Epsilon:  1.0 , Reward -272.5970537564127 , mean_reward:  -195.74034823060984 , time_score:  81 , memory:  157243
# Episode:  1720  , Epsilon:  1.0 , Reward -176.10568576017857 , mean_reward:  -192.7762474984226 , time_score:  64 , memory:  157675
# Episode:  1725  , Epsilon:  1.0 , Reward -149.13052995017932 , mean_reward:  -190.10338462932773 , time_score:  118 , memory:  158078
# Episode:  1730  , Epsilon:  1.0 , Reward -165.87583443258927 , mean_reward:  -190.51701194049375 , time_score:  111 , memory:  158635
# Episode:  1735  , Epsilon:  1.0 , Reward -245.20337270441757 , mean_reward:  -188.84142742996963 , time_score:  115 , memory:  159082
# Episode:  1740  , Epsilon:  1.0 , Reward -168.5387051175673 , mean_reward:  -189.03414049380604 , time_score:  62 , memory:  159501
# Episode:  1745  , Epsilon:  1.0 , Reward -90.09498762344492 , mean_reward:  -186.18414820905724 , time_score:  87 , memory:  159922
# Episode:  1750  , Epsilon:  1.0 , Reward -111.56230462276234 , mean_reward:  -180.97683677395716 , time_score:  72 , memory:  160429
# Episode:  1755  , Epsilon:  1.0 , Reward -149.57801861021483 , mean_reward:  -171.3497146412191 , time_score:  81 , memory:  160803
# Episode:  1760  , Epsilon:  1.0 , Reward -101.62475263266272 , mean_reward:  -164.8071468283836 , time_score:  132 , memory:  161316
# Episode:  1765  , Epsilon:  1.0 , Reward -121.57789554502908 , mean_reward:  -157.76332147178428 , time_score:  102 , memory:  161845
# Episode:  1770  , Epsilon:  1.0 , Reward -151.1169260061985 , mean_reward:  -157.32726144412484 , time_score:  82 , memory:  162279
# Episode:  1775  , Epsilon:  1.0 , Reward -44.9979614845695 , mean_reward:  -160.51086930515132 , time_score:  105 , memory:  162746
# Episode:  1780  , Epsilon:  1.0 , Reward -81.59163417766001 , mean_reward:  -163.4128844886497 , time_score:  72 , memory:  163174
# Episode:  1785  , Epsilon:  1.0 , Reward -160.38506965926993 , mean_reward:  -161.0973689758494 , time_score:  80 , memory:  163617
# Episode:  1790  , Epsilon:  1.0 , Reward -128.49871606143256 , mean_reward:  -162.45438168207065 , time_score:  73 , memory:  164012
# Episode:  1795  , Epsilon:  1.0 , Reward -314.7757000886238 , mean_reward:  -158.34628478433982 , time_score:  135 , memory:  164463
# Episode:  1800  , Epsilon:  1.0 , Reward -102.19554645655072 , mean_reward:  -163.3924903186836 , time_score:  65 , memory:  164992
# Episode:  1805  , Epsilon:  1.0 , Reward -313.85844112950906 , mean_reward:  -169.97692923800386 , time_score:  94 , memory:  165425
# Episode:  1810  , Epsilon:  1.0 , Reward -139.44463518253988 , mean_reward:  -167.68607198021792 , time_score:  89 , memory:  165840
# Episode:  1815  , Epsilon:  1.0 , Reward -55.309654320905864 , mean_reward:  -168.32705961637276 , time_score:  61 , memory:  166300
# Episode:  1820  , Epsilon:  1.0 , Reward -82.06648918604992 , mean_reward:  -174.78722425859752 , time_score:  96 , memory:  166809
# Episode:  1825  , Epsilon:  1.0 , Reward -178.32599386508423 , mean_reward:  -175.2772670849067 , time_score:  67 , memory:  167268
# Episode:  1830  , Epsilon:  1.0 , Reward -105.57335786667566 , mean_reward:  -174.49976274306624 , time_score:  130 , memory:  167765
# Episode:  1835  , Epsilon:  1.0 , Reward -378.7106179026905 , mean_reward:  -179.14100226317896 , time_score:  113 , memory:  168244
# Episode:  1840  , Epsilon:  1.0 , Reward -208.131096838382 , mean_reward:  -179.47861393770052 , time_score:  96 , memory:  168680
# Episode:  1845  , Epsilon:  1.0 , Reward -129.58733828209267 , mean_reward:  -180.23660137459376 , time_score:  131 , memory:  169234
# Episode:  1850  , Epsilon:  1.0 , Reward -129.63450431527306 , mean_reward:  -184.15221482889964 , time_score:  110 , memory:  169701
# Episode:  1855  , Epsilon:  1.0 , Reward -137.62832493344143 , mean_reward:  -185.6763472101961 , time_score:  71 , memory:  170133
# Episode:  1860  , Epsilon:  1.0 , Reward -223.39847625393895 , mean_reward:  -192.54165454556858 , time_score:  62 , memory:  170569
# Episode:  1865  , Epsilon:  1.0 , Reward -214.41343263650145 , mean_reward:  -196.6673283495868 , time_score:  136 , memory:  171090
# Episode:  1870  , Epsilon:  1.0 , Reward -355.1122266677779 , mean_reward:  -198.20598326995687 , time_score:  94 , memory:  171479
# Episode:  1875  , Epsilon:  1.0 , Reward -83.43937117240179 , mean_reward:  -201.58939892939827 , time_score:  81 , memory:  171935
# Episode:  1880  , Epsilon:  1.0 , Reward -192.38024682227228 , mean_reward:  -199.42891801784498 , time_score:  101 , memory:  172385
# Episode:  1885  , Epsilon:  1.0 , Reward -192.11629890051387 , mean_reward:  -196.3332293526993 , time_score:  76 , memory:  172787
# Episode:  1890  , Epsilon:  1.0 , Reward -187.49313057165296 , mean_reward:  -195.83676407097244 , time_score:  71 , memory:  173212
# Episode:  1895  , Epsilon:  1.0 , Reward -136.3487150682346 , mean_reward:  -191.32095242303703 , time_score:  136 , memory:  173716
# Episode:  1900  , Epsilon:  1.0 , Reward -169.1435999823525 , mean_reward:  -187.72769838400964 , time_score:  76 , memory:  174157
# Episode:  1905  , Epsilon:  1.0 , Reward -132.39563351962107 , mean_reward:  -181.6413740027096 , time_score:  67 , memory:  174530
# Episode:  1910  , Epsilon:  1.0 , Reward -156.2859408188202 , mean_reward:  -182.35918733973978 , time_score:  102 , memory:  174991
# Episode:  1915  , Epsilon:  1.0 , Reward -232.218326823908 , mean_reward:  -182.75988970875423 , time_score:  93 , memory:  175464
# Episode:  1920  , Epsilon:  1.0 , Reward -397.69580451848003 , mean_reward:  -183.04424007156874 , time_score:  69 , memory:  175894
# Episode:  1925  , Epsilon:  1.0 , Reward -194.7699632532935 , mean_reward:  -181.71187572629614 , time_score:  122 , memory:  176391
# Episode:  1930  , Epsilon:  1.0 , Reward -213.84971478547848 , mean_reward:  -185.20486735707786 , time_score:  88 , memory:  176859
# Episode:  1935  , Epsilon:  1.0 , Reward -101.30936592792479 , mean_reward:  -178.53713863757895 , time_score:  138 , memory:  177361
# Episode:  1940  , Epsilon:  1.0 , Reward -236.09528380213402 , mean_reward:  -183.84386717995534 , time_score:  97 , memory:  177779
# Episode:  1945  , Epsilon:  1.0 , Reward -440.79992843707726 , mean_reward:  -189.34761945937993 , time_score:  96 , memory:  178205
# Episode:  1950  , Epsilon:  1.0 , Reward -122.21099565665882 , mean_reward:  -191.74724150274795 , time_score:  141 , memory:  178707
# Episode:  1955  , Epsilon:  1.0 , Reward -124.27215225178513 , mean_reward:  -190.32175957930366 , time_score:  90 , memory:  179221
# Episode:  1960  , Epsilon:  1.0 , Reward -86.72643937160369 , mean_reward:  -187.47068095152844 , time_score:  80 , memory:  179675
# Episode:  1965  , Epsilon:  1.0 , Reward -293.95203703984896 , mean_reward:  -186.7476566960112 , time_score:  88 , memory:  180159
# Episode:  1970  , Epsilon:  1.0 , Reward -112.5077023257718 , mean_reward:  -190.51068388131583 , time_score:  120 , memory:  180635
# Episode:  1975  , Epsilon:  1.0 , Reward -309.4798517009598 , mean_reward:  -186.8434794925398 , time_score:  85 , memory:  181104
# Episode:  1980  , Epsilon:  1.0 , Reward -119.37776598734067 , mean_reward:  -187.40993964987425 , time_score:  135 , memory:  181587
# Episode:  1985  , Epsilon:  1.0 , Reward -357.4767369589462 , mean_reward:  -188.600439225412 , time_score:  78 , memory:  182016
# Episode:  1990  , Epsilon:  1.0 , Reward -296.7108559252599 , mean_reward:  -196.35477242957546 , time_score:  105 , memory:  182532
# Episode:  1995  , Epsilon:  1.0 , Reward -64.74060075560344 , mean_reward:  -197.92447342324954 , time_score:  72 , memory:  183003

# %%
df
# Out:
#       Episode  Epsilon      Reward  Mean_Reward   Time
# 0         0.0      1.0 -333.656274  -333.656274   74.0
# 1         1.0      1.0 -133.859094  -233.757684   73.0
# 2         2.0      1.0 -141.404814  -202.973394   64.0
# 3         3.0      1.0 -206.605124  -203.881327   78.0
# 4         4.0      1.0 -278.662353  -218.837532  141.0
# ...       ...      ...         ...          ...    ...
# 1995   1995.0      1.0  -64.740601  -197.924473   72.0
# 1996   1996.0      1.0   24.479868  -196.823689   90.0
# 1997   1997.0      1.0 -222.181263  -197.873368   79.0
# 1998   1998.0      1.0 -133.223345  -198.072073  106.0
# 1999   1999.0      1.0 -136.140023  -198.022602  104.0
#
# [2000 rows x 5 columns]

# %%
df.iloc[:,1:4].plot()
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns

# %%
fig, ax1 = plt.subplots()

color = 'tab:green'
ax1.set_xlabel('Episodes')
ax1.set_ylabel('Reward')
ax1.plot(df.iloc[:,0], df.iloc[:,2:3], color=color)
ax1.plot(df.iloc[:,0], df.iloc[:,3:4], color='red')
ax1.tick_params(axis='y')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Epsilon')  # we already handled the x-label with ax1
ax2.plot(df.iloc[:,0], df.iloc[:,1:2], color=color)
ax2.tick_params(axis='y')

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
